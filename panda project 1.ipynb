# %%
import pandas as pd
import numpy as nd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("sales.csv",encoding='unicode escape')
data
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
data.drop(["Status","unnamed1"],axis=1,inplace=True)

# %%
data
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
data.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
data.dropna(inplace=True)
data
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
data.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
ds1=data.groupby(["Age Group"],as_index=False)["Amount"].sum()
x=ds1["Age Group"]
ds2=data.groupby(["Age Group"],as_index=False)["Amount"].size()
ds2
# Out:
#   Age Group  size
# 0      0-17   296
# 1     18-25  1879
# 2     26-35  4541
# 3     36-45  2283
# 4     46-50   983
# 5     51-55   830
# 6       55+   427

# %%
y=ds1["Amount"]
y
y2=ds2["size"]
y2

a=[]
for i in y2:
    a.append(i*30000)

# %%
plt.bar(x,a)
plt.plot(x,y,color="r")

plt.show()

# %%
data["Gender"]=data["Gender"].replace({"F":"Female","M":"Male"})

# %%
data
# Out:
#        User_ID    Cust_name Product_ID  Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942  Female     26-35   28               0
# 1      1000732       Kartik  P00110942  Female     26-35   35               1
# 2      1001990        Bindu  P00118542  Female     26-35   35               1
# 3      1001425       Sudevi  P00237842    Male      0-17   16               0
# 4      1000588         Joni  P00057942    Male     26-35   28               1
# ...        ...          ...        ...     ...       ...  ...             ...
# 11246  1000695      Manning  P00296942    Male     18-25   19               1
# 11247  1004089  Reichenbach  P00171342    Male     26-35   33               0
# 11248  1001209        Oshin  P00201342  Female     36-45   40               0
# 11249  1004023       Noonan  P00059442    Male     36-45   37               0
# 11250  1002744      Brumley  P00281742  Female     18-25   19               0
#
# ...

# %%
def chg(p):
    if p==0:
        return "Unmarried"
    else:
        return "Married"

# %%
data["MS"]=data["Marital_Status"].apply(chg)
data
# Out:
#        User_ID    Cust_name Product_ID  Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942  Female     26-35   28               0
# 1      1000732       Kartik  P00110942  Female     26-35   35               1
# 2      1001990        Bindu  P00118542  Female     26-35   35               1
# 3      1001425       Sudevi  P00237842    Male      0-17   16               0
# 4      1000588         Joni  P00057942    Male     26-35   28               1
# ...        ...          ...        ...     ...       ...  ...             ...
# 11246  1000695      Manning  P00296942    Male     18-25   19               1
# 11247  1004089  Reichenbach  P00171342    Male     26-35   33               0
# 11248  1001209        Oshin  P00201342  Female     36-45   40               0
# 11249  1004023       Noonan  P00059442    Male     36-45   37               0
# 11250  1002744      Brumley  P00281742  Female     18-25   19               0
#
# ...

# %%
ds4=data.groupby(["Gender"],as_index=False)["Amount"].sum()
ds4
# Out:
#    Gender       Amount
# 0  Female  74335856.43
# 1    Male  31913276.00

# %%
x1=ds4["Gender"]
x1
# Out:
# 0    Female
# 1      Male
# Name: Gender, dtype: object

# %%
y1=ds4["Amount"]
y1
# Out:
# 0    74335856.43
# 1    31913276.00
# Name: Amount, dtype: float64

# %%
plt.pie(y1,labels=["Female","Male"],autopct='%1.2f')
plt.show()

# %%
ds5=data.groupby(["Occupation"],as_index=False)["Amount"].sum()
ds5
# Out:
#          Occupation       Amount
# 0       Agriculture   2593087.00
# 1        Automobile   5368596.00
# 2          Aviation  12602298.00
# 3           Banking  10770610.95
# 4          Chemical   5297436.00
# 5      Construction   3597511.00
# 6   Food Processing   4070670.00
# 7              Govt   8517212.00
# 8        Healthcare  13034587.49
# 9       Hospitality   6376405.00
# 10        IT Sector  14755079.00
# 11           Lawyer   4981665.00
# 12            Media   6295832.99
# 13           Retail   4783170.00
# 14          Textile   3204972.00

# %%
D=ds5["Occupation"]
D
# Out:
# 0         Agriculture
# 1          Automobile
# 2            Aviation
# 3             Banking
# 4            Chemical
# 5        Construction
# 6     Food Processing
# 7                Govt
# 8          Healthcare
# 9         Hospitality
# 10          IT Sector
# 11             Lawyer
# 12              Media
# 13             Retail
# 14            Textile
# Name: Occupation, dtype: object

# %%
D=ds5["Amount"]
D
# Out:
# 0      2593087.00
# 1      5368596.00
# 2     12602298.00
# 3     10770610.95
# 4      5297436.00
# 5      3597511.00
# 6      4070670.00
# 7      8517212.00
# 8     13034587.49
# 9      6376405.00
# 10    14755079.00
# 11     4981665.00
# 12     6295832.99
# 13     4783170.00
# 14     3204972.00
# Name: Amount, dtype: float64

# %%
D=ds5["Occupation"]
B=ds5["Amount"]
plt.figure(figsize=(18,6))
plt.bar(D,B)

for i in range(len(B)):
    plt.text(i,B[i]//2,str(B[i]),va='center')

plt.show()
